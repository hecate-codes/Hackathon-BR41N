# %%
import mne
from mne.decoding import CSP
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
import json

from mne.decoding import CSP
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

from mne.filter import filter_data

# %%
data_train = np.load("datos_procesados/P1_post_training.mat.npz")
data_test = np.load("datos_procesados/P1_post_test.mat.npz")

X_train = data_train["X"]
y_train = data_train["y"]

X_test = data_test["X"]
y_test = data_test["y"]

print("Shape train:", X_train.shape, y_train.shape)
print("Shape test:", X_test.shape, y_test.shape)
# Out:
# Shape train: (320, 384, 16) (320,)
# Shape test: (320, 384, 16) (320,)

# %%
X_train = np.transpose(X_train, (0, 2, 1))
X_test = np.transpose(X_test, (0, 2, 1))

X_train = filter_data(X_train, sfreq=256, l_freq=8, h_freq=30)
X_test = filter_data(X_test, sfreq=256, l_freq=8, h_freq=30)

csp = CSP(n_components=4, log=True)
lda = LinearDiscriminantAnalysis()

clf = Pipeline([
    ('csp', csp),
    ('lda', lda)
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print(f'Accuracy: {acc:.3f}')
# Out:
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 423 samples (1.652 s)
# C:\Users\rschu\AppData\Local\Temp\ipykernel_25512\497120677.py:4: RuntimeWarning: filter_length (423) is longer than the signal (384), distortion is likely. Reduce filter length or filter a longer signal.
#   X_train = filter_data(X_train, sfreq=256, l_freq=8, h_freq=30)
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 423 samples (1.652 s)
# C:\Users\rschu\AppData\Local\Temp\ipykernel_25512\497120677.py:5: RuntimeWarning: filter_length (423) is longer than the signal (384), distortion is likely. Reduce filter length or filter a longer signal.
#   X_test = filter_data(X_test, sfreq=256, l_freq=8, h_freq=30)
# Computing rank from data with rank=None
#     Using tolerance 23 (2.2e-16 eps * 16 dim * 6.5e+15  max singular value)
#     Estimated rank (data): 16
#     data: rank 16 computed from 16 data channels with 0 projectors
# Reducing data rank from 16 -> 16
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Accuracy: 0.787
